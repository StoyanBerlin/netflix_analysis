# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as Sns

# %%
nflix_df = pd.read_csv("netflix_titles_2.csv")                                      # df -> dataframe

# %%
nflix_df.head(10)                                 # Die ersten 10 Zeilen
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
nflix_df.tail(10)                                                     # Die letzten 10 Zeilen
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
nflix_df.info()                                               # Inhalt der Spalte und Datentypen
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
nflix_df.describe()                                   # mean Durchschnitt
                                                # std Standardabweichung
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
nflix_df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#df.dropna()

# %%
# df_int = df["intensity"]                           # Zeigt eine Spalte aus der ganzen Tabelle

# %%
#pd.DataFrame(data = df_int)

# %%
# df_clean = pd.DataFrame(df, columns= ["year", "hour", "intensity", "country", "location_name", "total_deaths", "total_damage_millions_dollars" ])
# Erstellt neue Tabelle aus gewünschten Spalten

# %%
nflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
nflix_df['date_added'] = pd.to_datetime(nflix_df['date_added'], infer_datetime_format = True)
nflix_df['year_added'] = nflix_df['date_added'].dt.year

# %%
nflix_df.year_added.sort_values(na_position='first').head(12)
# Out:
# 6066       NaN
# 6174       NaN
# 6795       NaN
# 6806       NaN
# 6901       NaN
# 7196       NaN
# 7254       NaN
# 7406       NaN
# 7847       NaN
# 8182       NaN
# 5957    2008.0
# 6611    2008.0
# Name: year_added, dtype: float64

# %%
nflix_df = nflix_df.drop(index =[6066, 6174, 6795, 6806, 6901, 7196, 7254, 7406, 7847, 8182 ])

# %%
nflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8797 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8797 non-null   object
#  1   type          8797 non-null   object
#  2   title         8797 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7972 non-null   object
#  5   country       7967 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8797 non-null   int64
#  8   rating        8793 non-null   object
#  9   duration      8794 non-null   object
#  10  listed_in     8797 non-null   object
#  11  description   8797 non-null   object
#  12  year_added    8797 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(10)
# memory usage: 962.2+ KB

# %%
nflix_df["year_added"] = nflix_df["year_added"].astype('int64')

# %%
nflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8797 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8797 non-null   object
#  1   type          8797 non-null   object
#  2   title         8797 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7972 non-null   object
#  5   country       7967 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8797 non-null   int64
#  8   rating        8793 non-null   object
#  9   duration      8794 non-null   object
#  10  listed_in     8797 non-null   object
#  11  description   8797 non-null   object
#  12  year_added    8797 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(10)
# memory usage: 962.2+ KB

# %%
movies = nflix_df[nflix_df.type == "Movie"]

# %%
movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6131 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6131 non-null   object
#  1   type          6131 non-null   object
#  2   title         6131 non-null   object
#  3   director      5943 non-null   object
#  4   cast          5656 non-null   object
#  5   country       5691 non-null   object
#  6   date_added    6131 non-null   datetime64[ns]
#  7   release_year  6131 non-null   int64
#  8   rating        6129 non-null   object
#  9   duration      6128 non-null   object
#  10  listed_in     6131 non-null   object
#  11  description   6131 non-null   object
#  12  year_added    6131 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(10)
# memory usage: 670.6+ KB

# %%
tv_shows = nflix_df[nflix_df.type == "TV Show"]

# %%
Duration = []
for x in movies["duration"]:
    Duration.append(x.split(' ')[0])

movies["Duration"] = Duration

   
movies.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/34/ffq98nzj7js6rz07x57739vc0000gn/T/ipykernel_38284/2818361395.py in <module>
#       1 Duration = []
#       2 for x in movies["duration"]:
# ----> 3     Duration.append(x.split(' ')[0])
#       4
#       5 movies["Duration"] = Duration
#
# AttributeError: 'float' object has no attribute 'split'

# %%
movies['duration'] = movies['duration'].str.replace('min', '')
# Out:
# /var/folders/34/ffq98nzj7js6rz07x57739vc0000gn/T/ipykernel_38284/3520878233.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['duration'] = movies['duration'].str.replace('min', '')

# %%
movies.isna().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        188
# cast            475
# country         440
# date_added        0
# release_year      0
# rating            2
# duration          3
# listed_in         0
# description       0
# year_added        0
# dtype: int64

# %%
movies = movies.dropna()

# %%
movies['duration'] = movies['duration'].str.replace(' ', '').astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/34/ffq98nzj7js6rz07x57739vc0000gn/T/ipykernel_38284/1618957616.py in <module>
# ----> 1 movies['duration'] = movies['duration'].str.replace(' ', '').astype('float')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5185 entries, 7 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5185 non-null   object
#  1   type          5185 non-null   object
#  2   title         5185 non-null   object
#  3   director      5185 non-null   object
#  4   cast          5185 non-null   object
#  5   country       5185 non-null   object
#  6   date_added    5185 non-null   datetime64[ns]
#  7   release_year  5185 non-null   int64
#  8   rating        5185 non-null   object
#  9   duration      5185 non-null   float64
#  10  listed_in     5185 non-null   object
#  11  description   5185 non-null   object
#  12  year_added    5185 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 567.1+ KB

# %%
tv_shows
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
tv_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2666 entries, 1 to 8803
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       2666 non-null   object
#  1   type          2666 non-null   object
#  2   title         2666 non-null   object
#  3   director      230 non-null    object
#  4   cast          2316 non-null   object
#  5   country       2276 non-null   object
#  6   date_added    2666 non-null   datetime64[ns]
#  7   release_year  2666 non-null   int64
#  8   rating        2664 non-null   object
#  9   duration      2666 non-null   object
#  10  listed_in     2666 non-null   object
#  11  description   2666 non-null   object
#  12  year_added    2666 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(10)
# memory usage: 291.6+ KB

# %%
6131  / 8807  # 70% movies
# Out:
# 0.6961507891449983

# %%
2676 / 8807 # 30% TV Shows
# Out:
# 0.3038492108550017

# %%
plt.figure(figsize = (13, 6))
labels = ['TV Show', 'Movie']
plt.pie(nflix_df['type'].value_counts().sort_values(),labels = labels, colors = ['lightblue', 'lightslategrey'], autopct ='%1.2f%%', startangle = 90)
plt.title('Type of Netflix Content 2008-2021')
plt.legend(labels = ['TV Show', 'Movie'], loc = 'upper right')
plt.show()

# %%
type_year = (nflix_df.groupby(['type','year_added'])['title'].size().reset_index())

fig = plt.figure(figsize=(13,6))
Sns.lineplot(x = 'year_added',y = 'title', data = type_year, style = 'type', hue ='type', size = 'type', markers = True, palette = 'deep')
plt.title("Type Trend 2008-2021")

plt.show()

# %%
plt.figure(figsize=(15,7))
Sns.countplot(nflix_df["country"],hue = nflix_df["type"],order = nflix_df["country"].value_counts().index[:10], data = nflix_df, palette = 'deep')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='country', ylabel='count'>

# %%
movies.country.value_counts().head(20)
# Out:
# United States                    1819
# India                             868
# United Kingdom                    164
# Canada                            104
# Egypt                              90
# Spain                              84
# Nigeria                            84
# Indonesia                          76
# Turkey                             74
# Philippines                        73
# Japan                              73
# France                             68
# Mexico                             63
# United Kingdom, United States      59
# United States, Canada              50
# Hong Kong                          49
# Brazil                             42
# Germany                            41
# South Korea                        38
# Thailand                           36
# Name: country, dtype: int64

# %%
movies.country.value_counts().tail(20)
# Out:
# United States, Israel, United Kingdom, Canada                            1
# United Kingdom, China, United States                                     1
# Spain, United Kingdom                                                    1
# Denmark, Sweden, Israel, United States                                   1
# Slovenia, Croatia, Germany, Czech Republic, Qatar                        1
# South Africa, Angola                                                     1
# Portugal, France, Poland, United States                                  1
# Singapore, Japan, France                                                 1
# United Kingdom, Germany, Canada                                          1
# France, Germany, Czech Republic, Belgium                                 1
# United States, China, Colombia                                           1
# United Kingdom, New Zealand                                              1
# ...

# %%
movies.rating.value_counts().head(20)
# Out:
# TV-MA       1741
# TV-14       1177
# R            778
# PG-13        470
# TV-PG        416
# PG           275
# TV-G          81
# TV-Y          71
# TV-Y7         70
# NR            58
# G             40
# TV-Y7-FV       3
# UR             3
# NC-17          2
# Name: rating, dtype: int64

# %%
count_genre = (nflix_df.set_index('title').listed_in.str.split(",", expand = True).stack().value_counts().sort_values(ascending = False).iloc[:30])
print(count_genre)
# Out:
#  International Movies         2624
# Dramas                        1600
# Comedies                      1210
# Action & Adventure             859
# Documentaries                  829
#  Dramas                        827
# International TV Shows         773
#  Independent Movies            736
#  TV Dramas                     695
#  Romantic Movies               613
# Children & Family Movies       605
#  International TV Shows        577
#  Thrillers                     512
#  Comedies                      464
#  TV Comedies                   455
# Crime TV Shows                 399
# Kids' TV                       386
#  Music & Musicals              357
#  Romantic TV Shows             338
# Stand-Up Comedy                334
# Horror Movies                  275
# British TV Shows               252
#  Sci-Fi & Fantasy              230
# Docuseries                     220
#  Sports Movies                 218
# Anime Series                   175
#  Docuseries                    174
# ...

# %%
count_genre = (movies.set_index('title').listed_in.str.split(",", expand = True).str.replace(' ', '').stack().value_counts().sort_values(ascending = False).iloc[:30])
print(count_genre)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/34/ffq98nzj7js6rz07x57739vc0000gn/T/ipykernel_38284/45343926.py in <module>
# ----> 1 count_genre = (movies.set_index('title').listed_in.str.split(",", expand = True).str.replace(' ', '').stack().value_counts().sort_values(ascending = False).iloc[:30])
#       2 print(count_genre)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
count_genre.listed_in.str.replace(' ', '')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/34/ffq98nzj7js6rz07x57739vc0000gn/T/ipykernel_38284/2522695531.py in <module>
# ----> 1 count_genre.listed_in.str.replace(' ', '')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'listed_in'

# %%
count_genre.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/34/ffq98nzj7js6rz07x57739vc0000gn/T/ipykernel_38284/3156871678.py in <module>
# ----> 1 count_genre.type()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
movies.listed_in.value_counts().head(20)
# Out:
# Dramas, International Movies                        336
# Stand-Up Comedy                                     286
# Comedies, Dramas, International Movies              257
# Dramas, Independent Movies, International Movies    243
# Children & Family Movies, Comedies                  179
# Dramas, International Movies, Romantic Movies       160
# Documentaries                                       156
# Comedies, International Movies                      152
# Comedies, International Movies, Romantic Movies     143
# Dramas                                              133
# Children & Family Movies                            132
# Action & Adventure                                  127
# Dramas, International Movies, Thrillers             125
# Comedies, Dramas, Independent Movies                114
# Action & Adventure, Dramas, International Movies    111
# Comedies                                            100
# Dramas, Independent Movies                          100
# ...

# %%
count_genre_movies = (movies.set_index('title').listed_in.str.split(",", expand = True).stack().value_counts().sort_values(ascending = False).iloc[:30])
print(count_genre_movies)
# Out:
#  International Movies        2624
# Dramas                       1600
# Comedies                     1210
# Action & Adventure            859
# Documentaries                 829
#  Dramas                       827
#  Independent Movies           736
#  Romantic Movies              613
# Children & Family Movies      605
#  Thrillers                    512
#  Comedies                     464
#  Music & Musicals             357
# Stand-Up Comedy               334
# Horror Movies                 275
#  Sci-Fi & Fantasy             230
#  Sports Movies                218
# International Movies          128
#  LGBTQ Movies                 101
#  Horror Movies                 82
# Classic Movies                 80
#  Faith & Spirituality          65
# Thrillers                      65
#  Cult Movies                   59
# Movies                         57
#  Anime Features                50
#  Documentaries                 40
#  Classic Movies                36
# ...

# %%
count_genre_tv_shows = (tv_shows.set_index('title').listed_in.str.split(",", expand = True).stack().value_counts().sort_values(ascending = False).iloc[:30])
print(count_genre_tv_shows)
# Out:
# International TV Shows           773
#  TV Dramas                       695
#  International TV Shows          577
#  TV Comedies                     455
# Crime TV Shows                   399
# Kids' TV                         386
#  Romantic TV Shows               338
# British TV Shows                 252
# Docuseries                       220
# Anime Series                     175
#  Docuseries                      174
#  Spanish-Language TV Shows       171
#  Korean TV Shows                 151
#  Reality TV                      135
#  TV Action & Adventure           128
# Reality TV                       120
# TV Comedies                      119
#  TV Mysteries                     98
#  Science & Nature TV              92
#  TV Sci-Fi & Fantasy              82
#  Crime TV Shows                   70
#  Teen TV Shows                    69
# TV Dramas                         67
#  TV Horror                        64
#  Kids' TV                         63
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5185 entries, 7 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5185 non-null   object
#  1   type          5185 non-null   object
#  2   title         5185 non-null   object
#  3   director      5185 non-null   object
#  4   cast          5185 non-null   object
#  5   country       5185 non-null   object
#  6   date_added    5185 non-null   datetime64[ns]
#  7   release_year  5185 non-null   int64
#  8   rating        5185 non-null   object
#  9   duration      5185 non-null   float64
#  10  listed_in     5185 non-null   object
#  11  description   5185 non-null   object
#  12  year_added    5185 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 567.1+ KB

# %%
nflix_df = nflix_df.rename(columns={" International Movies " : "International Movies", " Dramas " : "Dramas" , " Independent Movies " : "Independent Movies", " TV Dramas " : "TV Dramas", " Romantic Movies " : "Romantic Movies" }, inplace=True)

# %%
count_genre = (nflix_df.set_index('title').listed_in.str.split(",", expand = True).stack().value_counts().sort_values(ascending = False).iloc[:30])
print(count_genre)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/34/ffq98nzj7js6rz07x57739vc0000gn/T/ipykernel_38284/1213063183.py in <module>
# ----> 1 count_genre = (nflix_df.set_index('title').listed_in.str.split(",", expand = True).stack().value_counts().sort_values(ascending = False).iloc[:30])
#       2 print(count_genre)
#
# AttributeError: 'NoneType' object has no attribute 'set_index'

# %%
# Viz of the top 20 genres:
genre_list = nflix_df.set_index('title').listed_in.str.split(",",expand=True).stack().reset_index(level = 1, drop = True)
plt.figure(figsize=(13,6))
Sns.countplot(y = genre_list, order = genre_list.value_counts().index[:20], palette = 'deep')
plt.show()

# %%
# Viz of the top 20 genres:
genre_list = movies.set_index('title').listed_in.str.split(",",expand=True).stack().reset_index(level = 1, drop = True)
plt.figure(figsize=(13,6))
Sns.countplot(y = genre_list, order = genre_list.value_counts().index[:20], palette = 'deep')
plt.show()

# %%
# Set country index, str split listed-in, expand then stack back, reset index
genre_list = nflix_df.set_index('country').listed_in.str.split(",",expand=True).stack().reset_index( level = 1, drop = True)

# %%
genre_list
# Out:
# country
# United States               Documentaries
# South Africa       International TV Shows
# South Africa                    TV Dramas
# South Africa                 TV Mysteries
# NaN                        Crime TV Shows
#                            ...
# United States    Children & Family Movies
# United States                    Comedies
# India                              Dramas
# India                International Movies
# India                    Music & Musicals
# Length: 19303, dtype: object

# %%
#Df the output
df = pd.DataFrame(genre_list).reset_index()

# %%
df
# Out:
#              country                         0
# 0      United States             Documentaries
# 1       South Africa    International TV Shows
# 2       South Africa                 TV Dramas
# 3       South Africa              TV Mysteries
# 4                NaN            Crime TV Shows
# ...              ...                       ...
# 19298  United States  Children & Family Movies
# 19299  United States                  Comedies
# 19300          India                    Dramas
# 19301          India      International Movies
# 19302          India          Music & Musicals
#
# [19303 rows x 2 columns]

# %%
# Get the US only
df2 = df[df['country'] == 'United States']

# %%
df2
# Out:
#              country                         0
# 0      United States             Documentaries
# 21     United States                  Comedies
# 22     United States                    Dramas
# 36     United States               TV Comedies
# 37     United States                 TV Dramas
# ...              ...                       ...
# 19292  United States                 Thrillers
# 19296  United States                  Comedies
# 19297  United States             Horror Movies
# 19298  United States  Children & Family Movies
# 19299  United States                  Comedies
#
# [4990 rows x 2 columns]

# %%
df3 = movies[movies["country"] == "Nigeria"]
df3
# Out:
#      show_id   type                                   title  \
# 73       s74  Movie                            King of Boys
# 84       s85  Movie                    Omo Ghetto: the Saga
# 281     s282  Movie                           Brother Jekwu
# 298     s299  Movie                            Quam's Money
# 306     s307  Movie                                     '76
# ...      ...    ...                                     ...
# 7875   s7876  Movie                       Road to Yesterday
# 8227   s8228  Movie                              The Bridge
# 8241   s8242  Movie                                 The CEO
# 8297   s8298  Movie                The Figurine (Araromire)
# 8556   s8557  Movie  The Wedding Party 2: Destination Dubai
#
#                         director  \
# 73                  Kemi Adetiba
# 84    JJC Skillz, Funke Akindele
# 281              Charles Uwagbai
# 298                 Kayode Kasum
# 306                   Izu Ojukwu
# ...                          ...
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 73 to 8556
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       84 non-null     object
#  1   type          84 non-null     object
#  2   title         84 non-null     object
#  3   director      84 non-null     object
#  4   cast          84 non-null     object
#  5   country       84 non-null     object
#  6   date_added    84 non-null     datetime64[ns]
#  7   release_year  84 non-null     int64
#  8   rating        84 non-null     object
#  9   duration      84 non-null     float64
#  10  listed_in     84 non-null     object
#  11  description   84 non-null     object
#  12  year_added    84 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 9.2+ KB

# %%
df3 = df[df['country'] == 'India']

# %%
df3.describe()
# Out:
#        release_year    duration   year_added
# count     84.000000   84.000000    84.000000
# mean    2017.178571  108.023810  2019.809524
# std        2.747006   18.412919     1.091878
# min     2003.000000   67.000000  2015.000000
# 25%     2016.000000   98.000000  2019.000000
# 50%     2018.000000  105.500000  2020.000000
# 75%     2019.000000  115.000000  2021.000000
# max     2021.000000  182.000000  2021.000000

# %%
nigerian_market = movies['listed_in'].value_counts()
nigerian_market
# Out:
# Dramas, International Movies                                336
# Stand-Up Comedy                                             286
# Comedies, Dramas, International Movies                      257
# Dramas, Independent Movies, International Movies            243
# Children & Family Movies, Comedies                          179
#                                                            ...
# Action & Adventure, Classic Movies, International Movies      1
# Action & Adventure, Horror Movies, Independent Movies         1
# Comedies, Cult Movies, Sci-Fi & Fantasy                       1
# Comedies, Dramas, Sports Movies                               1
# Cult Movies, Horror Movies, Thrillers                         1
# Name: listed_in, Length: 268, dtype: int64

# %%
nigerian_directors = movies['director'].value_counts()
nigerian_directors
# Out:
# Raúl Campos, Jan Suter      18
# Marcus Raboy                14
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Jay Chapman                 12
#                             ..
# Katherine Fairfax Wright     1
# Arthur Penn                  1
# Yuki Tanada                  1
# Mark Herman                  1
# Dileep Narayanan             1
# Name: director, Length: 3828, dtype: int64

# %%
nigerian_actors = movies['cast'].value_counts()
nigerian_actors.head(20)
# Out:
# Samuel West             10
# Jeff Dunham              7
# Kevin Hart               6
# Jim Gaffigan             5
# Bill Burr                5
# Jay O. Sanders           4
# Tom Segura               4
# Craig Sechler            4
# Bill Hicks               4
# Vir Das                  4
# Iliza Shlesinger         4
# Bo Burnham               3
# Sam Kinison              3
# Rachael Stirling         3
# Jerry Seinfeld           3
# Sebastian Maniscalco     3
# John Mulaney             3
# Eric Meyers              3
# Marc Maron               3
# Mike Birbiglia           3
# Name: cast, dtype: int64

# %%
tv_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2666 entries, 1 to 8803
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       2666 non-null   object
#  1   type          2666 non-null   object
#  2   title         2666 non-null   object
#  3   director      230 non-null    object
#  4   cast          2316 non-null   object
#  5   country       2276 non-null   object
#  6   date_added    2666 non-null   datetime64[ns]
#  7   release_year  2666 non-null   int64
#  8   rating        2664 non-null   object
#  9   duration      2666 non-null   object
#  10  listed_in     2666 non-null   object
#  11  description   2666 non-null   object
#  12  year_added    2666 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(10)
# memory usage: 291.6+ KB

# %%
tv_shows['duration'] = tv_shows['duration'].str.replace('Seasons', '')
# Out:
# /var/folders/34/ffq98nzj7js6rz07x57739vc0000gn/T/ipykernel_38284/2628150547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows['duration'] = tv_shows['duration'].str.replace('Seasons', '')

# %%
tv_shows['duration'] = tv_shows['duration'].str.replace('Season', '')
# Out:
# /var/folders/34/ffq98nzj7js6rz07x57739vc0000gn/T/ipykernel_38284/3412715305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows['duration'] = tv_shows['duration'].str.replace('Season', '')

# %%
tv_shows
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
tv_shows['duration'] = tv_shows['duration'].astype('int')
# Out:
# /var/folders/34/ffq98nzj7js6rz07x57739vc0000gn/T/ipykernel_38284/4217022853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows['duration'] = tv_shows['duration'].astype('int')

# %%
tv_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2666 entries, 1 to 8803
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       2666 non-null   object
#  1   type          2666 non-null   object
#  2   title         2666 non-null   object
#  3   director      230 non-null    object
#  4   cast          2316 non-null   object
#  5   country       2276 non-null   object
#  6   date_added    2666 non-null   datetime64[ns]
#  7   release_year  2666 non-null   int64
#  8   rating        2664 non-null   object
#  9   duration      2666 non-null   int64
#  10  listed_in     2666 non-null   object
#  11  description   2666 non-null   object
#  12  year_added    2666 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(9)
# memory usage: 291.6+ KB

# %%
tv_shows.country.value_counts().head(20)
# Out:
# United States            754
# United Kingdom           212
# Japan                    168
# South Korea              158
# India                     79
# Taiwan                    68
# Canada                    59
# France                    49
# Spain                     48
# Australia                 47
# Mexico                    40
# China                     38
# Turkey                    29
# Brazil                    27
# Thailand                  24
# Colombia                  22
# United States, Canada     22
# Germany                   20
# Argentina                 18
# Singapore                 17
# Name: country, dtype: int64

# %%
# Joining Rows of D column into a big chunk text then plot
str1 = " ".join(description for description in nflix_df.description) # Another solution to joining text into one big chunk of text

plt.figure(figsize=[12,15])
plot_d = WordCloud(stopwords = STOPWORDS, collocations = False, background_color = 'white', max_font_size = 90, max_words = 200).generate(str1)
plt.imshow(plot_d, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/34/ffq98nzj7js6rz07x57739vc0000gn/T/ipykernel_38284/517321986.py in <module>
#       3
#       4 plt.figure(figsize=[12,15])
# ----> 5 plot_d = WordCloud(stopwords = STOPWORDS, collocations = False, background_color = 'white', max_font_size = 90, max_words = 200).generate(str1)
#       6 plt.imshow(plot_d, interpolation='bilinear')
#       7 plt.axis("off")
#
# NameError: name 'WordCloud' is not defined

# %%
nflix_df.to_csv("netflix_data_clean.csv")
